# %% [markdown]
# <a href="https://colab.research.google.com/github/wimasy/invstr/blob/main/1/yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
from yfinance import EquityQuery
q = EquityQuery('and', [
       EquityQuery('gt', ['percentchange', 3]),
       EquityQuery('eq', ['region', 'id']),
       EquityQuery('gte', ['intradaymarketcap',  2000000000]),
       EquityQuery('gte', ['intradayprice', 5]),
       EquityQuery('gt', ['dayvolume', 15000])
])
response = yf.screen(q, sortField = 'percentchange', sortAsc = True)
print(response)

# %%
data=yf.Ticker("BBCA.JK")
data.info

# %%
data.history(interval='5d')

# %%
data.history(period='5d')

# %%
data.history(start="2025-01-01",end="2025-01-15")

# %%
from yfinance import EquityQuery
q = EquityQuery('and', [
       EquityQuery('gt', ['percentchange', 3]),
       EquityQuery('eq', ['region', 'id'])
])
response = yf.screen(q, sortField = 'percentchange', sortAsc = True)
print(response)

# %%
data=yf.download("BBCA.JK BBRI.JK BMRI.JK",start="2025-01-01",end="2025-02-01")

# %%
print(data['Close']['BBCA.JK'])

# %%
data.cash_flow

# %%
data.quarterly_balance_sheet
